# %%
""" 
    DocString: 

    Introduction - This game is based on the movide Coco from pixar. Having watch the movie can help with answers. 
    Recap video: https://www.youtube.com/watch?v=ddk9spE1na8
    
    The game consists of a start function, a fail function and the functions for all four possible scenes:
    1. Choosing which relative to look for
        2.1 Looking for either Ernesto
        2.1 Inmelda
        2.2 Hector
    3. Ernesto House and getting back to the land of the living
    4. Helping Coco remember 
    
    Known bugs or errors - the possible answer list for the ernesto_house function might me too restrictive. 
    
"""
#importing packages needed to run the game
from sys import exit
import random

#The function start will give the intial introduction to the game
def start():
    print(""">>> 'Miguel gets transported to the land of the death. 
    He is told he must get back to the land of the living before sunrise, 
    in order to do so he must get a family member’s blessing.' \n""")
    
    input(prompt = "Press enter if you want to help him get back. \n") #asking the user for action to continue.
    print("*"*110)
    first_decision() #calling the next scenario to be played

#In the first decision function the user is asked to choose between one of three possible options.
def first_decision():
    print(""">>> 'After border patrol lets Miguel go he has to look for his family 
    to get their blessing.'
    
    Who should he look for?:
        1. His famous great-great-grandfather Ernesto de la Cruz 
        2. His great-great-grandmother Imelda 
        3. Take his chances and look around. \n""")
    
    decision1 = input(prompt="\nAnswer: ").casefold() #declaring decision1 into prompt, holds user input
    #use of casefold to avoid comparing answers with capital letters to answers in lowercase
    
    #conditional loop based on user input
    if decision1 == "1" or "ernesto" in decision1 or "grandfather" in decision1:
        input(prompt="Press enter to continue. \n")
        print("*"*110)
        ernesto_decision() #takes to the ernesto scenario function
    
    elif decision1 == "2" or "imelda" in decision1 or "grandmother" in decision1:
        input(prompt="Press enter to continue. \n")
        print("*"*110)
        imelda_decision() #takes to the imelda scenario function
    
    elif decision1 == "3" or "look" in decision1 or "chances" in decision1:
        input(prompt="Press enter to continue. \n")
        print("*"*110)
        another_decision() #takes to the hector scenario function
    
    else:
        print(">>> Invalid entry. Please try again. \n") #in case answer doesn't match possible answers, user can retry
        first_decision() #calling the same scenario for user to answer again

# Scenario 2.1. In This function the idea is to simulate the talent show.
def ernesto_decision():
    print(""">>> 'The way to meet Ernesto is to win the local talent show.'
    What should Miguel perform at the show? \n""")
    
    #setting the user inputs into the needed objects for the dynamic string
    instrument = input(prompt = "Choose a musical instrument to play: ").casefold()
    song = input(prompt= "Choose a song: ").casefold()
    artist = input(prompt= "Which artist wrote the song? ").casefold()
    song_verse = input(prompt= "Write your favorite part of the song. It can be just one line: ").casefold()
    
    #template into which the answers provided above will be shown with the use of f string.
    print(f""" \n >>> PRESENTER: 'Now doing a cover of {song} by {artist} is Miguel playing the {instrument}'.
     MIGUEL: '{song_verse}...' \n""")
    input(prompt="Press enter to continue. \n")
    print(">>> 'Miguel won the music contest and he has been invited to Ernesto's house.' \n")
    input(prompt="Press enter to continue.\n")
    print("*"*110)
    ernesto_house() #calling the next scenario

#scenario 2.2. In this function the idea is to give only two possible outcomes for the user.
#To end the game or go back to the previous scenario to choose a different outcome. 
def imelda_decision():
    print(""">>> 'Miguel found his grandmother Imelda at the shoe workshop. 
    As he tells her about what happened she agrees to help him if he promises 
    one thing...to never sing again.'
    
    What should Miguel do?
        1. Accept and go back to the land of the living.
        2. Refuse and look for another family member for help. \n""")
    
    decision2 = input(prompt = "Answer: ") #user input for answer
    
    #conditional statement based on user input
    if decision2 == "1" or "accept" in decision2:
        print(">>> Imelda gives Miguel her blessing, but to get back Miguel must decipher the message:")
        message = ["The",'day',"when","our",'ancestors',"come","and","visit","us"] # setting the message into a list
        scrambled = random.shuffle(message) #scambling the message with shuffle
        print(message) #showing the scambled message
        
        #looping until the player guesses correctly the messsage, infinite trials with True statement.
        while True:
            answer = input(prompt="\nAnswer: ").casefold()
        
            if answer == "the day when our ancestors come and visit us":
                print("\n>>> Miguel has gone back to the land of the living but he will never be able to sing again.\n")
                break #finishing the loop and game.

            else:
                print("That's incorrect, try again. Check your spelling and avoid spaces at the end of the sentence.")

    elif decision2 == "2" or "refuse" in decision2 or "another" in decision2 or "look" in decision2:
        input(prompt="Press enter to continue.\n")
        print("*"*110)
        first_decision() #going to a scenario before to choose different path
    
    else:
        print(">>> Invalid entry. Please try again.\n")
        imelda_decision() #calling same scenario so user can try again their response

#scenario 2.3. In this scenario de user is asked to answer one question correctly, given three trials. 
#Will be given different question each time guess is incorrect.
def another_decision():
    print(""">>> 'As Miguel is walking around he meets Hector, who claims to know Ernesto de la Cruz and offers his help. 
    He says that the way to get to Ernesto is to sneak into his house. 
    
    As they are trying to get into the house a security guard caught them. 
    Miguel tells the guard he is Ernesto’s grandchild.
    
    The guard says that if Miguel can answer right a question about Ernesto he’ll let them through.' 
    Miguel has three oportunities. \n""")
    
    questions = [ "What is Ernesto’s last name?", "What instrument did Ernesto played?", 
                 "Which town was Ernesto from?", "How did Ernesto died?", 
                 "Which was Ernesto's most famous song?"] #list of possible questions for user
    
    trials = 3 #setting the count of trials available to user
    
    while trials > 0: # setting a loop to give the user questions as long as there are trials available
        question = random.choice(questions) #selecting a question randomly from the list
        print(f""">>> {question} \n""") #using print to show the question to user
        
        if question == questions[0]: #telling the game how to proceed based on the question gotten from random
            answer_0 = input(prompt="Answer here: ").casefold() #asking for user input
            if "de la cruz" in answer_0: #setting another loop to compare the answer to the possible answers
                print("\n>>> GUARD: 'You really know him, you can come in.'")
                input(prompt="Press enter to continue.")
                print("*"*110)
                ernesto_house() #calling to the next scenario in case of correct answer
            else:
                trials -= 1 #if answer not correct a trial will be deducted.
                print(f"\n>>> That's not the correct answer. You have {trials} trial(s) left. \n ") #showing user how many trials are left
                
        elif question == questions[1]:
            answer_1 = input(prompt="Answer here: ").casefold()
            if "guitar" in answer_1:
                print("\n>>> GUARD: 'You really know him, you can come in.' \n")
                input(prompt="Press enter to continue.")
                print("*"*110)
                ernesto_house()
            else:
                trials -= 1
                print(f"\n>>> That's not the correct answer. You have {trials} trial(s) left. \n ")
       
        elif question == questions[2]:
                answer_2 = input(prompt="Answer here: ").casefold()
                if "santa cecilia" in answer_2:
                    print("\n>>> GUARD: 'You really know him, you can come in.' \n")
                    input(prompt="Press enter to continue.")
                    print("*"*110)
                    ernesto_house()
                else:
                    trials -= 1
                    print(f"\n>>> That's not the correct answer. You have {trials} trial(s) left. \n ")

        elif question == questions[3]:
                answer_3 = input(prompt="Answer here: ").casefold()
                if "bell" in answer_3:
                    print("\n>>> GUARD: 'You really know him, you can come in.' \n")
                    input(prompt="Press enter to continue.")
                    print("*"*110)
                    ernesto_house()
                else:
                    trials -= 1
                    print(f"\n>>> That's not the correct answer. You have {trials} trial(s) left. \n ")

        elif question == questions[4]:
                answer_4 = input(prompt="Answer here: ").casefold()
                if "remember me" in answer_4:
                    print("\n>>> GUARD: 'You really know him, you can come in.' \n")
                    input(prompt="Press enter to continue.")
                    print("*"*110)
                    ernesto_house()
                else:
                    trials -= 1
                    print(f"\n>>> That's not the correct answer. You have {trials} trial(s) left. \n ")
                    
        else:
            print("Something went wrong. Try again") #if user answer doesn't match possible answers
            another_decision() #calling same scenario
    
    else: #if user runs out of guesses he/she looses. Fail function allows to replay game
        print("\n>>> GUARD: 'You don't know Ernesto, you cannot come in.' \n")
        fail() 

#In this scenario the user has to choose the correct answer, else the game will end. 
def ernesto_house():
    
    #setting variables with different options for flowers
    mexican_flower = ['cempasuchil','dahlia','passiflora', 'mexican sunflower']
    other_flower = ['daisy','rose','violet','bugambilia','iris','tulip','carnation','lotus','cherry blossom','peony','orchid']
    #randomly selecting the different options to display
    random_mexican = random.choice(mexican_flower)
    random_other_one = random.choice(other_flower)
    random_other_two = random.choice(other_flower)
    #setting variables with different possible answers for conditional loop
    mexican_answers = ['cempasuchil','cempazuchil','dahlia','dalia','dhalia','passiflora','pasiflora', 'mexican sunflower','sunflower']
    other_answers = ['daisy','daisys','rose','rosse','rosee','violet','violett','bugambilia','bugamvilia','iris','iriss',
                     'tulip','tulips','carnation','canration','lotus','cherry blossom','cherry','blossom','peony','peonie','orchid']
    
    #imputing the variables for the different options selected into an f string 
    print(f""">>> 'Miguel found Ernesto, but soon finds out he is not actually his great-great-grandfather.
    
    Hector who was Ernesto’s friend and band member is Miguel's grandfather.
    Hector needs Miguel's help to make Mamá Coco remember him and not disappear from the land of the death. 
    
    Hector gives Miguel his blessing, a flower petal. 
    For the blessing to work Miguel has to say correctly the name of the flower in his hands.'
    
    What is the correct type of flower? 
    
    hint: its a mexican specie.
    
        1. {random_mexican} 
        2. {random_other_one}
        3. {random_other_two}
    \n """)
    
    flower_choice = input(prompt="Answer: ").casefold() #user input for answer
    
    #conditional statement based on user input
    if flower_choice in other_answers: #comparing to list of possible answers
        print("\n>>> That was not the correct flower, the blessing didn’t work.\n")
        fail() #this will call the fail function which allows for replaying the game
                 
    elif flower_choice in mexican_answers:
        print("\n>>> The blessing worked, Miguel can now go to the land of the living. \n")
        input(prompt="Press enter to continue. \n")
        print("*"*110)
        help_coco() #takes to the final scenario 
        
    else:
        print("\n>>> Invalid entry. Please check your spelling. \n")
        input(prompt="Press enter to continue. \n")
        ernesto_house()

#In this scenario the user has to choose the correct answer otherwise the game will end. 
def help_coco():
    
    lyrics = ["Remember",'me',"though","I",'have',"to","say","goodbye","remember","me"] # setting the message into a list
    scrambled = random.shuffle(lyrics) #scambling the lyrics with shuffle

    
    print(f""">>> 'Miguel is back in the land of the living.
    In order to help Mamá Coco remember Hector, Miguel  must sing correctly their song.'
    
    can you help him order the song lyrics?\n """)
    print(lyrics) #showing the shuffled lyrics
                 
    song_decision = input(prompt="\nAnswer: ").casefold() #user input for answer
        
    #conditional statement based on the user input
    if song_decision == 'remember me though i have to say goodbye remember me':
        print("""\n>>> You helped Coco remember Hector, now the whole family can 
        celebrate 'Día de los muertos' together!\n""")
        print("🇫​​​​​🇪​​​​​🇱​​​​​🇮​​​​​🇿 🇩​​​​​🇮​​​​​🇦​​​​​ 🇩​​​​​🇪​​​​​ 🇱​​​​​🇴​​​​​🇸​​​​​ 🇲​​​​​🇺​​​​​🇪​​​​​🇷​​​​​🇹​​​​​🇴​​​​​🇸​​​​​!")
        # link for the ascii art: https://fsymbols.com/text-art/
        exit() #shutting off the game 
        
    else:
        print("\n>>> Try again. Check your spelling and avoid spaces at the end of the sentence. \n")
        input(prompt="Press enter to continue.\n")
        help_coco() #calling the same scenario to try again

def fail():
    print(">>> The game has ended. Thank you for playing! \n")
    print("*"*110)
    print("Do you want to play again? Answer yes/no. \n") #allowing the user to replay by asking a specific answer.
    play_again = input(prompt=">>> \n").casefold() #user input for answer
    if play_again == "yes": #conditional statement based on user input
        print("*"*110)
        start() #going to the begining of the game
    
    elif play_again == "no":
        exit() #shutting of the game
        
    else:
        print("Something went wrong")
        fail() #if answer doesn't match possible answers, the same function is called.

start() #starting the game
# Out:
# >>> 'Miguel gets transported to the land of the death.
#     He is told he must get back to the land of the living before sunrise,
#     in order to do so he must get a family member’s blessing.'
#
# Press enter if you want to help him get back.
#
# **************************************************************************************************************
# >>> 'After border patrol lets Miguel go he has to look for his family
#     to get their blessing.'
#
#     Who should he look for?:
#         1. His famous great-great-grandfather Ernesto de la Cruz
#         2. His great-great-grandmother Imelda
#         3. Take his chances and look around.
#
#
# Answer: 1
# Press enter to continue.
#
# **************************************************************************************************************
# >>> 'The way to meet Ernesto is to win the local talent show.'
#     What should Miguel perform at the show?
#
# Choose a musical instrument to play: guitar
# ...
